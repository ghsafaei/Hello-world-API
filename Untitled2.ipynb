# %% [markdown]
# <a href="https://colab.research.google.com/github/ghsafaei/Hello-world-API/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
import requests

response = requests.get("http://google.com/")

print(response.text)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
